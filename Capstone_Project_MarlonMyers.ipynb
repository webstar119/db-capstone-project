# %%
try:
    print("Importing MySQL Connector/Python API...")
    import mysql.connector as connector
    from datetime import datetime as dt
    from mysql.connector.pooling import MySQLConnectionPool
    print("MySQL Connector/Python API is imported successfully...\n")
    
except Error as err:
    print("Error code:", err.errno)
    print("Error message:", err.msg)

try: 
    print("Importing MySQL Error from Connector/Python API...")
    from mysql.connector import Error
    print("MySQL Eror from Connector/Python API is imported successfully...\n")

except Error as err:
    print("Error Code:", err.errno)
    print("Error message:", err.msg)
# Out:
# Importing MySQL Connector/Python API...
# MySQL Connector/Python API is imported successfully...
#
# Importing MySQL Error from Connector/Python API...
# MySQL Eror from Connector/Python API is imported successfully...

# %%
print("Establishing a new connection between MySQL and Python...")
try:
    connection = connector.connect(
        host="localhost",         # or your server IP / hostname
        user="root",              # your MySQL username
        password="Test_Password123", # your MySQL password
        #database=""  # database name
    )
    print("A connection between MySQL and Python is successfully established...")
    print("Connected:", connection.is_connected())

except Error as err:
    print("Error code:", err.errno)
    print("Error message:", err.msg)
    print("There is an error with host/password/username")
    print("There is an error with host password and/or username")
# Out:
# Establishing a new connection between MySQL and Python...
# A connection between MySQL and Python is successfully established...
# Connected: True

# %%
cursor = connection.cursor()

# %%
buffered_cursor = connection.cursor(buffered = True)

# %%
dictionary_cursor = connection.cursor(dictionary = True)

# %%
show_tables_query = "SHOW tables" 
cursor.execute(show_tables_query)

# %%
results = cursor.fetchall()
print(cursor.column_names)
# Out:
# ('Tables_in_littlelemondb',)

# %%
cursor.execute("USE littlelemondb")

# %%
print(results)
# Out:
# [('bookings',), ('customers',), ('menu',), ('menuitems',), ('ordering_table',), ('orderitems',), ('orders',), ('orderstatus',), ('ordersview',), ('ordersview2',), ('orderview3',), ('staff',)]

# %%
select_stmt ="""
Select Concat(C.FirstName," ", C.LastName) as FullName, C.Cell, C.Email, O.TotalCost
from Orders as O
inner join Bookings as B
on B.BookingID = O.BookingID
inner join Customers as C
on C.CustomerID = B.CustomerID
"""

# %%
cursor.execute(select_stmt)

# %%
results = cursor.fetchall()
print(cursor.column_names)
for result in results:
    print(result)
# Out:
# ('FullName', 'Cell', 'Email', 'TotalCost')
# ('Vanessa McCarthy', '757536378', 'vanessa@example.com', Decimal('38'))
# ('Marcos Romero', '757536379', 'marcos@example.com', Decimal('28'))
# ('Hiroki Yamane', '757536376', 'hiroki@example.com', Decimal('46'))
# ('Diana Pinto', '757536374', 'diana@example.com', Decimal('26'))
# ('Aaliyah Johnson', '7185551001', 'aaliyah@example.com', Decimal('58'))
# ('David Chen', '7185551002', 'davidchen@example.com', Decimal('45'))
# ('Fatima Ali', '7185551003', 'fatima@example.com', Decimal('34'))
# ('Christopher Green', '7185551004', 'chrisgreen@example.com', Decimal('50'))
# ('Isabella Lopez', '7185551005', 'isabella@example.com', Decimal('24'))
# ('Kevin Thomas', '7185552001', 'kevin@example.com', Decimal('70'))
# ('Rachel Adams', '7185552002', 'rachel@example.com', Decimal('73'))
# ('Malik Carter', '7185552003', 'malik@example.com', Decimal('102'))

# %%
select_stmt2 ="""
Select Concat(C.FirstName," ", C.LastName) as FullName, C.Cell, C.Email, O.TotalCost
from Orders as O
inner join Bookings as B
on B.BookingID = O.BookingID
inner join Customers as C
on C.CustomerID = B.CustomerID
where O.TotalCost > 60;
"""

# %%
cursor.execute(select_stmt2)

# %%
results = cursor.fetchall()
print(cursor.column_names)
for result in results:
    print(result)
# Out:
# ('FullName', 'Cell', 'Email', 'TotalCost')
# ('Kevin Thomas', '7185552001', 'kevin@example.com', Decimal('70'))
# ('Rachel Adams', '7185552002', 'rachel@example.com', Decimal('73'))
# ('Malik Carter', '7185552003', 'malik@example.com', Decimal('102'))

# %%
results = cursor.fetchall()
print(cursor.column_names)
for result in results:
    print(result)
# Out:
# ('FullName', 'Cell', 'Email', 'TotalCost')
